# %% [markdown]
# # Code : Courbes avec torsion

# %%
def EllipticCurve_with_order(m, *, D=None):
    r"""
    Return an iterator for elliptic curves over finite fields with the given order. The curves are
    computed using the Complex Multiplication (CM) method.

    A :class:`~sage.structure.factorization.Factorization` can be passed for ``m``, in which case
    the algorithm is more efficient.

    If ``D`` is specified, it is used as the discriminant.

    EXAMPLES::

        sage: from sage.schemes.elliptic_curves.ell_finite_field import EllipticCurve_with_order
        sage: E = next(EllipticCurve_with_order(1234)); E  # random
        Elliptic Curve defined by y^2 = x^3 + 1142*x + 1209 over Finite Field of size 1237
        sage: E.order() == 1234
        True

    When ``iter`` is set, the function returns an iterator of all elliptic curves with the given
    order::

        sage: from sage.schemes.elliptic_curves.ell_finite_field import EllipticCurve_with_order
        sage: it = EllipticCurve_with_order(21); it
        <generator object EllipticCurve_with_order at 0x...>
        sage: E = next(it); E  # random
        Elliptic Curve defined by y^2 = x^3 + 6*x + 14 over Finite Field of size 23
        sage: E.order() == 21
        True
        sage: Es = [E] + list(it); Es  # random
        [Elliptic Curve defined by y^2 = x^3 + 6*x + 14 over Finite Field of size 23,
         Elliptic Curve defined by y^2 = x^3 + 12*x + 4 over Finite Field of size 23,
         Elliptic Curve defined by y^2 = x^3 + 5*x + 2 over Finite Field of size 23,
         Elliptic Curve defined by y^2 = x^3 + (z2+3) over Finite Field in z2 of size 5^2,
         Elliptic Curve defined by y^2 = x^3 + (2*z2+2) over Finite Field in z2 of size 5^2,
         Elliptic Curve defined by y^2 = x^3 + 7*x + 1 over Finite Field of size 19,
         Elliptic Curve defined by y^2 = x^3 + 17*x + 10 over Finite Field of size 19,
         Elliptic Curve defined by y^2 = x^3 + 5*x + 12 over Finite Field of size 17,
         Elliptic Curve defined by y^2 = x^3 + 9*x + 1 over Finite Field of size 17,
         Elliptic Curve defined by y^2 = x^3 + 7*x + 6 over Finite Field of size 17,
         Elliptic Curve defined by y^2 = x^3 + z3^2*x^2 + (2*z3^2+z3) over Finite Field in z3 of size 3^3,
         Elliptic Curve defined by y^2 = x^3 + (z3^2+2*z3+1)*x^2 + (2*z3^2+2*z3) over Finite Field in z3 of size 3^3,
         Elliptic Curve defined by y^2 = x^3 + (z3^2+z3+1)*x^2 + (2*z3^2+1) over Finite Field in z3 of size 3^3,
         Elliptic Curve defined by y^2 + (z4^2+z4+1)*y = x^3 over Finite Field in z4 of size 2^4,
         Elliptic Curve defined by y^2 + (z4^2+z4)*y = x^3 over Finite Field in z4 of size 2^4,
         Elliptic Curve defined by y^2 = x^3 + 18*x + 26 over Finite Field of size 29,
         Elliptic Curve defined by y^2 = x^3 + 11*x + 19 over Finite Field of size 29,
         Elliptic Curve defined by y^2 = x^3 + 4 over Finite Field of size 19,
         Elliptic Curve defined by y^2 = x^3 + 19 over Finite Field of size 31,
         Elliptic Curve defined by y^2 = x^3 + 4 over Finite Field of size 13]
        sage: all(E.order() == 21 for E in Es)
        True

    Indeed, we can verify that this is correct. Hasse's bounds tell us that
    `p \leq 50` (approximately), and the rest can be checked via bruteforce::

        sage: for p in prime_range(50):
        ....:     for j in range(p):
        ....:         E0 = EllipticCurve(GF(p), j=j)
        ....:         for Et in E0.twists():
        ....:             if Et.order() == 21:
        ....:                 assert any(Et.is_isomorphic(E) for E in Es)

    .. NOTE::

        The output curves are not deterministic, as :func:`EllipticCurve_finite_field.twists` is not
        deterministic. However, the order of the j-invariants and base fields is fixed.

    AUTHORS:

     - Gareth Ma and Giacomo Pope (Sage Days 123): initial version
    """
    from sage.arith.misc import is_prime_power, factor
    from sage.quadratic_forms.binary_qf import BinaryQF
    from sage.structure.factorization import Factorization
    from sage.schemes.elliptic_curves.cm import hilbert_class_polynomial

    def find_q(m, m4_fac, D):
        for t, _ in BinaryQF(1, 0, -D).solve_integer(m4_fac, _flag=3):
            yield m + 1 - t
            yield m + 1 + t

    if isinstance(m, Factorization):
        m4_fac = m * factor(4)
        m_val = m.value()
    else:
        m4_fac = factor(m * 4)
        m_val = m

    if D is None:
        Ds = (D for D in range(-1, -4 * m_val - 1, -1) if D % 4 in [0, 1])
    else:
        assert D < 0 and D % 4 in [0, 1]
        Ds = [D]

    seen = set()
    for D in Ds:
        for q in find_q(m_val, m4_fac, D):
            if not is_prime_power(q):
                continue

            H = hilbert_class_polynomial(D)
            for j0 in H.roots(ring=GF(q), multiplicities=False):
                E = EllipticCurve(j=j0)
                for Et in E.twists():
                    if any(Et.is_isomorphic(E) for E in seen):
                        continue
                    # This tests whether the curve has given order
                    if Et.has_order(m_val):
                        # TODO: remove after 38617
                        Et.set_order(m_val, check=False)
                        seen.add(Et)
                        yield Et,D

#it = EllipticCurve_with_order((2^32).factor())

#2^190 : torsion 2^12, définie sur p. disc = -7
#2^32 : 1er : torsion 2^16, définie sur p^2, disc = -3 
#      2ieme : torsion 2^11 définie sur p, disc = -7
#      Autres courbes interessantes
#      Probleme : h(-7) = 1. Solution à partir de -39

# %%
def EllipticCurve_with_Torsion(ell,size,tmin,nb_class,nb_curves = 1):

    # On cherche un exemple de courbe ordinaire où la ell^n-torsion est définie pour un certain n < size

    #On préfère un discriminant dont le nombre de classe n'est pas 1, pour travailler avec des idéaux non principaux

    card = ell^size
    it = EllipticCurve_with_order((card).factor())  #On choisit comme cardinal une puissance de deux, ici arbitraire
    Tmin = ell^tmin
    assert card%Tmin == 0
    nK = 1
    T = 1

    curves = []
    for i in range(nb_curves):
        while nK < nb_class or T < Tmin or E.is_supersingular():

            E,D = next(it)
            A = E.abelian_group()
            inv = A.invariants()
            if len(inv) == 2:
                assert inv[1] % inv[0] == 0
                T = inv[0]
            else:
                T = 1
            K.<rK> = QuadraticField(D)
            dK = K.discriminant()
            K.<rK> = QuadraticField(dK)
            nK = K.class_number()
            f = isqrt(D/dK)
            
        curves.append([E,D,f,T])
        
        E,D = next(it)
        A = E.abelian_group()
        inv = A.invariants()
        assert inv[1] % inv[0] == 0
        T = inv[0]
        K.<rK> = QuadraticField(D)
        dK = K.discriminant()
        K.<rK> = QuadraticField(dK)
        nK = K.class_number()
        f = isqrt(D/dK)
        
    return curves
   

EllipticCurve_with_Torsion(2,32,14,4,nb_curves = 4)
# Out:
# [[Elliptic Curve defined by y^2 = x^3 + 2857265638*x + 3935716393 over Finite Field of size 4295049217,
#   -39,
#   1,
#   16384],
#  [Elliptic Curve defined by y^2 = x^3 + 171428965*x + 4017496321 over Finite Field of size 4295049217,
#   -39,
#   1,
#   16384],
#  [Elliptic Curve defined by y^2 = x^3 + 3933984621*x + 2270346025 over Finite Field of size 4295049217,
#   -39,
#   1,
#   16384],
#  [Elliptic Curve defined by y^2 = x^3 + 2533512917*x + 1945338383 over Finite Field of size 4295049217,
#   -39,
#   1,
#   16384]]

# %%
def rec_traces(t,q,T1,Tmin,f,dK,nmax):
    traces = [2,t]
    torsions = [1,T1]
    n = 2
    test = 1
    while n <= nmax:
        tn = t*traces[n-1] - q*traces[n-2]
        traces.append(tn)
        Dm = tn^2 - 4*(q^n)
        fm = isqrt(Dm/dK)

        if dK%4 == 1 :
            a = int((tn - fm)/2)
        else :
            a = int(tn/2)
        Tn = gcd(a-1,fm/f)
        
        torsions.append(Tn)
        if Tn%Tmin == 0:
            test = Tn
        n = n + 1
    return traces, torsions, test

def EllipticCurve_with_lowTorsion_degmax(ell,size,tmin,degmax,nb_cards = 1,nb_class = 4,nb_curves = 1):

    # On cherche un exemple de courbe ordinaire où la ell^n-torsion est définie pour un certain n < size

    #On préfère un discriminant dont le nombre de classe n'est pas 1, pour travailler avec des idéaux non principaux
    
    Tmin = ell^tmin
    curves = []
    for _ in range(nb_cards):
        
        m = randint(ell^size, ell^(size+1))
        #while gcd(m,ell) != 1:
            #m = randint(ell^size, ell^(size+1))
            
        it = EllipticCurve_with_order(m)  #On choisit comme cardinal une puissance de deux, ici arbitraire
        
        for i in range(nb_curves):
            nK = 1
            test = 1
            securite = 0
            # On veut qu'une grande puissance de ell divise une torsion définie avant degmax
            # On veut fm premier avec ell ?
            while (nK < nb_class or test == 1 or E.is_supersingular()) and securite < 100:

                E,D = next(it)
                
                K.<rK> = QuadraticField(D)
                dK = K.discriminant()
                K.<rK> = QuadraticField(dK)
                nK = K.class_number()
                wK = (dK + rK)/2
                f = isqrt(D/dK)
                t = E.trace_of_frobenius()
                q = m + t - 1

                assert q == E.base_ring().cardinality()

                print('Candidat :',E,m,t,q,D)

                # Calculs Frobenius
            
                Dm = t^2 - 4*q
                fm = isqrt(Dm/dK)

                print('Frobenius :', Dm, fm)
    
                #Calcul Torsion rationelle
                
                if dK%4 == 1 :
                    a = int((t - fm)/2)
                else :
                    a = int(t/2)
                T1 = gcd(a-1,fm/f)

                print('Torsion initial :', T1)

                #Calcul torsions

                traces, torsions, test = rec_traces(t,q,T1,Tmin,f,dK,degmax)

                print('Liste torsion :', torsions)

                #Test si grande torsions
                
                # Verification torsion (inutile)

                #A = E.abelian_group()
                #inv = A.invariants()
                #if len(inv) == 2:
                    #assert inv[1] % inv[0] == 0
                    #T = inv[0]
                #else:
                    #T = 1
                #assert T1 == T

                #print('Verif T1 ok')

                #Emax = E.change_ring( E.base_ring().extension(degmax) )
                #A = Emax.abelian_group()

                
                #inv = A.invariants()
                #if len(inv) == 2:
                    #assert inv[1] % inv[0] == 0
                    #T = inv[0]
                #else:
                    #T = 1
                #assert torsions[-1] == T

                #print('Verif Tmax ok')
                
                securite = securite + 1

            if securite == 100:
                print('SECURITE ATTEINTE')
            curves.append([E,D,f,test])
    return curves

EllipticCurve_with_lowTorsion_degmax(2,32,4,12)
# Out:
# Candidat : Elliptic Curve defined by y^2 = x^3 + 4929607783*x + 4512654652 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -11
# Frobenius : -26630287299 49203
# Torsion initial : 11
# Liste torsion : [1, 11, 33, 154, 165, 209, 2772, 11, 165, 154, 627, 121, 2688840]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 1767366683*x + 5295213513 over Finite Field of size 8320676387 8320784131 -107743 8320676387 -91
# Frobenius : -21674151499 15433
# Torsion initial : 11
# Liste torsion : [1, 11, 11, 22, 55, 11, 44, 473, 165, 22, 11, 2783, 440]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 2567310493*x + 4066210248 over Finite Field of size 8320676387 8320784131 -107743 8320676387 -91
# Frobenius : -21674151499 15433
# Torsion initial : 11
# Liste torsion : [1, 11, 11, 22, 55, 11, 44, 473, 165, 22, 11, 2783, 440]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 8289030454*x + 5885390678 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -99
# Frobenius : -26630287299 49203
# Torsion initial : 11
# Liste torsion : [1, 11, 33, 154, 165, 209, 2772, 11, 165, 154, 627, 121, 2688840]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 5785591125*x + 1938768072 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -99
# Frobenius : -26630287299 49203
# Torsion initial : 11
# Liste torsion : [1, 11, 33, 154, 165, 209, 2772, 11, 165, 154, 627, 121, 2688840]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 4047679043*x + 4045899694 over Finite Field of size 8320644139 8320784131 -139991 8320644139 -219
# Frobenius : -13685096475 7905
# Torsion initial : 1
# Liste torsion : [1, 1, 3, 2, 15, 11, 36, 1, 255, 2, 33, 1, 360]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 489500543*x + 244917205 over Finite Field of size 8320644139 8320784131 -139991 8320644139 -219
# Frobenius : -13685096475 7905
# Torsion initial : 1
# Liste torsion : [1, 1, 3, 2, 15, 11, 36, 1, 255, 2, 33, 1, 360]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 801569861*x + 6376326660 over Finite Field of size 8320644139 8320784131 -139991 8320644139 -219
# Frobenius : -13685096475 7905
# Torsion initial : 1
# Liste torsion : [1, 1, 3, 2, 15, 11, 36, 1, 255, 2, 33, 1, 360]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 5960268467*x + 2190861354 over Finite Field of size 8320644139 8320784131 -139991 8320644139 -219
# Frobenius : -13685096475 7905
# Torsion initial : 1
# Liste torsion : [1, 1, 3, 2, 15, 11, 36, 1, 255, 2, 33, 1, 360]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 1243837649*x + 6917494131 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -539
# Frobenius : -26630287299 49203
# Torsion initial : 11
# Liste torsion : [1, 11, 33, 22, 165, 209, 396, 11, 165, 22, 627, 121, 384120]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 923340241*x + 5274742562 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -539
# Frobenius : -26630287299 49203
# Torsion initial : 11
# Liste torsion : [1, 11, 33, 22, 165, 209, 396, 11, 165, 22, 627, 121, 384120]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 4832396249*x + 665921328 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -539
# Frobenius : -26630287299 49203
# Torsion initial : 11
# Liste torsion : [1, 11, 33, 22, 165, 209, 396, 11, 165, 22, 627, 121, 384120]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 727372418*x + 5321203617 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -539
# Frobenius : -26630287299 49203
# Torsion initial : 11
# Liste torsion : [1, 11, 33, 22, 165, 209, 396, 11, 165, 22, 627, 121, 384120]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 3076494271*x + 5853595725 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -539
# Frobenius : -26630287299 49203
# Torsion initial : 11
# Liste torsion : [1, 11, 33, 22, 165, 209, 396, 11, 165, 22, 627, 121, 384120]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 7122331339*x + 5486367803 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -539
# Frobenius : -26630287299 49203
# Torsion initial : 11
# Liste torsion : [1, 11, 33, 22, 165, 209, 396, 11, 165, 22, 627, 121, 384120]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 1712351607*x + 5221804616 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -539
# Frobenius : -26630287299 49203
# Torsion initial : 11
# Liste torsion : [1, 11, 33, 22, 165, 209, 396, 11, 165, 22, 627, 121, 384120]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 5501891870*x + 5960187111 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -539
# Frobenius : -26630287299 49203
# Torsion initial : 11
# Liste torsion : [1, 11, 33, 22, 165, 209, 396, 11, 165, 22, 627, 121, 384120]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 1655512615*x + 5708920483 over Finite Field of size 8320703887 8320784131 -80243 8320703887 -579
# Frobenius : -26843876499 6809
# Torsion initial : 11
# Liste torsion : [1, 11, 11, 22, 55, 11, 8316, 11, 55, 22, 11, 121, 83160]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 7178809033*x + 147725856 over Finite Field of size 8320703887 8320784131 -80243 8320703887 -579
# Frobenius : -26843876499 6809
# Torsion initial : 11
# Liste torsion : [1, 11, 11, 22, 55, 11, 8316, 11, 55, 22, 11, 121, 83160]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 2877785957*x + 3499757974 over Finite Field of size 8320703887 8320784131 -80243 8320703887 -579
# Frobenius : -26843876499 6809
# Torsion initial : 11
# Liste torsion : [1, 11, 11, 22, 55, 11, 8316, 11, 55, 22, 11, 121, 83160]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 4693374174*x + 7897849258 over Finite Field of size 8320703887 8320784131 -80243 8320703887 -579
# Frobenius : -26843876499 6809
# Torsion initial : 11
# Liste torsion : [1, 11, 11, 22, 55, 11, 8316, 11, 55, 22, 11, 121, 83160]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 7035799009*x + 3567800310 over Finite Field of size 8320703887 8320784131 -80243 8320703887 -579
# Frobenius : -26843876499 6809
# Torsion initial : 11
# Liste torsion : [1, 11, 11, 22, 55, 11, 8316, 11, 55, 22, 11, 121, 83160]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 2818984673*x + 1309176173 over Finite Field of size 8320703887 8320784131 -80243 8320703887 -579
# Frobenius : -26843876499 6809
# Torsion initial : 11
# Liste torsion : [1, 11, 11, 22, 55, 11, 8316, 11, 55, 22, 11, 121, 83160]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 1485215995*x + 7766287929 over Finite Field of size 8320703887 8320784131 -80243 8320703887 -579
# Frobenius : -26843876499 6809
# Torsion initial : 11
# Liste torsion : [1, 11, 11, 22, 55, 11, 8316, 11, 55, 22, 11, 121, 83160]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 2573046467*x + 4581048125 over Finite Field of size 8320703887 8320784131 -80243 8320703887 -579
# Frobenius : -26843876499 6809
# Torsion initial : 11
# Liste torsion : [1, 11, 11, 22, 55, 11, 8316, 11, 55, 22, 11, 121, 83160]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 3679478438*x + 835258843 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -891
# Frobenius : -26630287299 49203
# Torsion initial : 11
# Liste torsion : [1, 11, 11, 154, 55, 209, 924, 11, 55, 154, 209, 121, 896280]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 7477397618*x + 5259274219 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -891
# Frobenius : -26630287299 49203
# Torsion initial : 11
# Liste torsion : [1, 11, 11, 154, 55, 209, 924, 11, 55, 154, 209, 121, 896280]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 6101280114*x + 4571958063 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -891
# Frobenius : -26630287299 49203
# Torsion initial : 11
# Liste torsion : [1, 11, 11, 154, 55, 209, 924, 11, 55, 154, 209, 121, 896280]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 3817934075*x + 3037395382 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -891
# Frobenius : -26630287299 49203
# Torsion initial : 11
# Liste torsion : [1, 11, 11, 154, 55, 209, 924, 11, 55, 154, 209, 121, 896280]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 281782978*x + 3262913116 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -891
# Frobenius : -26630287299 49203
# Torsion initial : 11
# Liste torsion : [1, 11, 11, 154, 55, 209, 924, 11, 55, 154, 209, 121, 896280]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 6881840527*x + 2967985619 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -891
# Frobenius : -26630287299 49203
# Torsion initial : 11
# Liste torsion : [1, 11, 11, 154, 55, 209, 924, 11, 55, 154, 209, 121, 896280]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 7675480715*x + 7824913248 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -1331
# Frobenius : -26630287299 49203
# Torsion initial : 1
# Liste torsion : [1, 1, 3, 14, 15, 19, 252, 1, 15, 14, 57, 11, 244440]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 63538734*x + 2710072193 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -1331
# Frobenius : -26630287299 49203
# Torsion initial : 1
# Liste torsion : [1, 1, 3, 14, 15, 19, 252, 1, 15, 14, 57, 11, 244440]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 2266471286*x + 2254760556 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -1331
# Frobenius : -26630287299 49203
# Torsion initial : 1
# Liste torsion : [1, 1, 3, 14, 15, 19, 252, 1, 15, 14, 57, 11, 244440]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 3762440231*x + 6248919921 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -1331
# Frobenius : -26630287299 49203
# Torsion initial : 1
# Liste torsion : [1, 1, 3, 14, 15, 19, 252, 1, 15, 14, 57, 11, 244440]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 2757747953*x + 1584854240 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -1331
# Frobenius : -26630287299 49203
# Torsion initial : 1
# Liste torsion : [1, 1, 3, 14, 15, 19, 252, 1, 15, 14, 57, 11, 244440]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 2432960765*x + 5926038281 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -1331
# Frobenius : -26630287299 49203
# Torsion initial : 1
# Liste torsion : [1, 1, 3, 14, 15, 19, 252, 1, 15, 14, 57, 11, 244440]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 5992056702*x + 5963077524 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -1331
# Frobenius : -26630287299 49203
# Torsion initial : 1
# Liste torsion : [1, 1, 3, 14, 15, 19, 252, 1, 15, 14, 57, 11, 244440]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 103423929*x + 2155399981 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -1331
# Frobenius : -26630287299 49203
# Torsion initial : 1
# Liste torsion : [1, 1, 3, 14, 15, 19, 252, 1, 15, 14, 57, 11, 244440]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 8120254598*x + 517693006 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -1331
# Frobenius : -26630287299 49203
# Torsion initial : 1
# Liste torsion : [1, 1, 3, 14, 15, 19, 252, 1, 15, 14, 57, 11, 244440]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 7688253226*x + 7305880152 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -1331
# Frobenius : -26630287299 49203
# Torsion initial : 1
# Liste torsion : [1, 1, 3, 14, 15, 19, 252, 1, 15, 14, 57, 11, 244440]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 6679558377*x + 4450916103 over Finite Field of size 8320702567 8320784131 -81563 8320702567 -1331
# Frobenius : -26630287299 49203
# Torsion initial : 1
# Liste torsion : [1, 1, 3, 14, 15, 19, 252, 1, 15, 14, 57, 11, 244440]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 7906829202*x + 669663292 over Finite Field of size 8320644139 8320784131 -139991 8320644139 -1971
# Frobenius : -13685096475 7905
# Torsion initial : 1
# Liste torsion : [1, 1, 1, 2, 5, 11, 12, 1, 85, 2, 11, 1, 120]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 6692258687*x + 5154631010 over Finite Field of size 8320644139 8320784131 -139991 8320644139 -1971
# Frobenius : -13685096475 7905
# Torsion initial : 1
# Liste torsion : [1, 1, 1, 2, 5, 11, 12, 1, 85, 2, 11, 1, 120]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 1469619622*x + 5881629190 over Finite Field of size 8320644139 8320784131 -139991 8320644139 -1971
# Frobenius : -13685096475 7905
# Torsion initial : 1
# Liste torsion : [1, 1, 1, 2, 5, 11, 12, 1, 85, 2, 11, 1, 120]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 1924482216*x + 45381171 over Finite Field of size 8320644139 8320784131 -139991 8320644139 -1971
# Frobenius : -13685096475 7905
# Torsion initial : 1
# Liste torsion : [1, 1, 1, 2, 5, 11, 12, 1, 85, 2, 11, 1, 120]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 7247365932*x + 965596682 over Finite Field of size 8320644139 8320784131 -139991 8320644139 -1971
# Frobenius : -13685096475 7905
# Torsion initial : 1
# Liste torsion : [1, 1, 1, 2, 5, 11, 12, 1, 85, 2, 11, 1, 120]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 8023750591*x + 7752955973 over Finite Field of size 8320644139 8320784131 -139991 8320644139 -1971
# Frobenius : -13685096475 7905
# Torsion initial : 1
# Liste torsion : [1, 1, 1, 2, 5, 11, 12, 1, 85, 2, 11, 1, 120]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 517235797*x + 2483377683 over Finite Field of size 8320644139 8320784131 -139991 8320644139 -1971
# Frobenius : -13685096475 7905
# Torsion initial : 1
# Liste torsion : [1, 1, 1, 2, 5, 11, 12, 1, 85, 2, 11, 1, 120]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 6728482897*x + 6230947184 over Finite Field of size 8320644139 8320784131 -139991 8320644139 -1971
# Frobenius : -13685096475 7905
# Torsion initial : 1
# Liste torsion : [1, 1, 1, 2, 5, 11, 12, 1, 85, 2, 11, 1, 120]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 8937080*x + 4283434901 over Finite Field of size 8320644139 8320784131 -139991 8320644139 -1971
# Frobenius : -13685096475 7905
# Torsion initial : 1
# Liste torsion : [1, 1, 1, 2, 5, 11, 12, 1, 85, 2, 11, 1, 120]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 3591399811*x + 1858340532 over Finite Field of size 8320644139 8320784131 -139991 8320644139 -1971
# Frobenius : -13685096475 7905
# Torsion initial : 1
# Liste torsion : [1, 1, 1, 2, 5, 11, 12, 1, 85, 2, 11, 1, 120]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 7090163868*x + 4794754740 over Finite Field of size 8320644139 8320784131 -139991 8320644139 -1971
# Frobenius : -13685096475 7905
# Torsion initial : 1
# Liste torsion : [1, 1, 1, 2, 5, 11, 12, 1, 85, 2, 11, 1, 120]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 4938744562*x + 6087522384 over Finite Field of size 8320644139 8320784131 -139991 8320644139 -1971
# Frobenius : -13685096475 7905
# Torsion initial : 1
# Liste torsion : [1, 1, 1, 2, 5, 11, 12, 1, 85, 2, 11, 1, 120]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 3533417914*x + 6759788884 over Finite Field of size 8320693063 8320784131 -91067 8320693063 -2163
# Frobenius : -24989573763 3399
# Torsion initial : 11
# Liste torsion : [1, 11, 33, 22, 33, 11, 396, 11, 33, 22, 33, 121, 792]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 5710435523*x + 7235085582 over Finite Field of size 8320693063 8320784131 -91067 8320693063 -2163
# Frobenius : -24989573763 3399
# Torsion initial : 11
# Liste torsion : [1, 11, 33, 22, 33, 11, 396, 11, 33, 22, 33, 121, 792]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 7935895843*x + 5986589426 over Finite Field of size 8320693063 8320784131 -91067 8320693063 -2163
# Frobenius : -24989573763 3399
# Torsion initial : 11
# Liste torsion : [1, 11, 33, 22, 33, 11, 396, 11, 33, 22, 33, 121, 792]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 1932527635*x + 1473470633 over Finite Field of size 8320693063 8320784131 -91067 8320693063 -2163
# Frobenius : -24989573763 3399
# Torsion initial : 11
# Liste torsion : [1, 11, 33, 22, 33, 11, 396, 11, 33, 22, 33, 121, 792]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 811525790*x + 6972600521 over Finite Field of size 8320693063 8320784131 -91067 8320693063 -2163
# Frobenius : -24989573763 3399
# Torsion initial : 11
# Liste torsion : [1, 11, 33, 22, 33, 11, 396, 11, 33, 22, 33, 121, 792]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 4730614016*x + 4208387208 over Finite Field of size 8320693063 8320784131 -91067 8320693063 -2163
# Frobenius : -24989573763 3399
# Torsion initial : 11
# Liste torsion : [1, 11, 33, 22, 33, 11, 396, 11, 33, 22, 33, 121, 792]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 862743885*x + 7500251280 over Finite Field of size 8320693063 8320784131 -91067 8320693063 -2163
# Frobenius : -24989573763 3399
# Torsion initial : 11
# Liste torsion : [1, 11, 33, 22, 33, 11, 396, 11, 33, 22, 33, 121, 792]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 5685988823*x + 6444265105 over Finite Field of size 8320693063 8320784131 -91067 8320693063 -2163
# Frobenius : -24989573763 3399
# Torsion initial : 11
# Liste torsion : [1, 11, 33, 22, 33, 11, 396, 11, 33, 22, 33, 121, 792]
# Candidat : Elliptic Curve defined by y^2 = x^3 + 3178733576*x + 4518016229 over Finite Field of size 8320611289 8320784131 -172841 8320611289 -2555
# Frobenius : -3408433875 1155
# Torsion initial : 11
# Liste torsion : [1, 11, 33, 88, 165, 11, 11088, 11, 165, 88, 33, 121, 110880]
# [[Elliptic Curve defined by y^2 = x^3 + 3178733576*x + 4518016229 over Finite Field of size 8320611289,
#   -2555,
#   1,
#   110880]]

# %%
def EllipticCurve_with_quadratic_2torsion(n, size_q, size_disc = 32, nb_curves = 1,maximale = False):

    # Renvoie un iterateur de courbes elliptiques définies sur un corps Fq,
    # telles que E[2^n] soit inclue dans E(F_q^2). 
    # size_q est un majorant du nombre de bits de q. 
    
    from sage.arith.misc import is_prime_power, factor
    from sage.quadratic_forms.binary_qf import BinaryQF
    from sage.structure.factorization import Factorization
    from sage.schemes.elliptic_curves.cm import hilbert_class_polynomial

    def candidat_t1(e0,f2,e1,t2,n):
        candidats = []
        facto = factor(e0)
        for f0 in facto :
            test_d = (ceil(e1/(f0[0]^2))).nbits() - 1
            dmin = floor((test_d + 2 + n - 1)/2)
            for d in range(dmin, n + 1):
                t1 = f0[0]*2^d
                if 2*t2 <= t1^2 :
                    candidats.append(t1)
        return candidats
        
    def is_discriminant(dK):
        K.<rK> = QuadraticField(dK)
        d_test = K.discriminant()
        return d_test == dK

    def diviseurs(n,maximale):
        facto = factor(n)
        if maximale:
            return [1] + [f[0] for f in facto]
        else:
            return [f[0] for f in facto]
        
    size_0 = ceil(size_q/2) - n            # f2^2 * |dK| = 4q^2 - t2^2 donc f2 < 2q grossièrement. On prend f2 < sqrt(q)
    size_1 = ceil(size_q/2) - n            # Autorise des discriminant de taille sqrt(q)
    assert size_0 > 0, "torsion demandée trop élevée."

    seen = set()
    curves = []
    while len(curves) != nb_curves :
    
        e0 = randint(1,2^size_0) 
        e1 = randint(1,2^size_1)
        
        f2 = (2^n)*e0
        tt2 = [ 2*( (2^n)*e1 + 1 ), 2*( (2^n)*e1 + (2^(n-1))*e0 + 1) ]
        for t2 in tt2:
            for t1 in candidat_t1(e0,f2,e1,t2,n):
                q = (t1^2 - t2)/2   #TODO essayer avec t2 et -t2
                if not is_prime_power(q):
                    continue
                D2 = t2^2 - 4*q^2
                dK = D2/(f2^2)
                if not is_discriminant(dK):
                    continue
                D1 = t1^2 - 4*q
                f1 = isqrt( D1/dK )
                for f in diviseurs(f1,maximale):
                    D = dK*f^2
                    H = hilbert_class_polynomial(D)
                    for j0 in H.roots(ring=GF(q), multiplicities=False):
                        E = EllipticCurve(j=j0)
                        for Et in E.twists():
                            if any(Et.is_isomorphic(E) for E in seen):
                                continue
                            assert Et.has_order(q + 1 - t1) or Et.has_order(q + 1 + t1)
                            seen.add(Et)
                            curves.append((Et,D))
                            if len(curves) == nb_curves:
                                return curves

# %%
Exemple = EllipticCurve_with_quadratic_2torsion(8,20,maximale = True)
(E, D) = Exemple[0]
E, D
# Out:
# (Elliptic Curve defined by y^2 = x^3 + 74*x + 49389 over Finite Field of size 130303,
#  -64767)

# %%
D.factor()
# Out:
# -1 * 3 * 21589

# %%
E.abelian_group()
# Out:
# Additive abelian group isomorphic to Z/65408 + Z/2 embedded in Abelian group of points on Elliptic Curve defined by y^2 = x^3 + 74*x + 49389 over Finite Field of size 130303

# %%
E2 = E.change_ring(E.base_ring().extension(2))
E2.abelian_group()
# Out:
# Additive abelian group isomorphic to Z/66323712 + Z/256 embedded in Abelian group of points on Elliptic Curve defined by y^2 = x^3 + 74*x + 49389 over Finite Field in z2 of size 130303^2

# %%
384.factor()
# Out:
# 2^7 * 3

# %%
def inverse_rec_traces(d,td,t1):
    # Etant donné le d-ieme terme td, teste s'il existe un entier q tel que la suite de traces parant de t1 mène à td
    # Teste ensuite si q est une puissance d'un nombre premier
    # On demande d >= 2

    from sage.arith.misc import is_prime_power
    
    rows = []
    j = 0
    PZ.<q> = PolynomialRing(QQ)
    for i in range(d - 1):
        row = [0]*(d+1)
        row[j] = 1
        row[j+1] = -t1
        row[j+2] = q
        j = j+1
        rows.append(row)
    row = [0]*(d+1)
    row[-1] = -t1
    row[-2] = 2
    rows.append(row)
    M = Matrix(PZ,rows)
    Ker = M.right_kernel()
    base = Ker.gens()
    assert base[0][d] == 1
    eq = (2*base[0])[0] - td
    sol = []
    for r in eq.roots() :
        if r[0] in ZZ:
            if is_prime_power(r[0]):
                sol.append(r[0])
    return sol


def EllipticCurve_with_2torsion_degree(d,n, size_q, size_disc = 32, nb_curves = 1,maximale = False):

    # Renvoie un iterateur de courbes elliptiques définies sur un corps Fq,
    # telles que E[2^n] soit inclue dans E(F_q^2). 
    # size_q est un majorant du nombre de bits de q. 
    
    from sage.arith.misc import is_prime_power, factor
    from sage.quadratic_forms.binary_qf import BinaryQF
    from sage.structure.factorization import Factorization
    from sage.schemes.elliptic_curves.cm import hilbert_class_polynomial

    def candidat_t1(e0,f2,e1,td,n):
        candidats = []
        facto = factor(e0)
        for f0 in facto :
            for k in range(n + 1):   #TODO estimer taille des candidats? 
                t1 = f0[0]*2^k
                candidats.append(t1)
        return candidats
        
    def is_discriminant(dK):
        K.<rK> = QuadraticField(dK)
        d_test = K.discriminant()
        return d_test == dK

    def diviseurs(n,maximale):
        facto = factor(n)
        if maximale:
            return [1] + [f[0] for f in facto]
        else:
            return [f[0] for f in facto]
        
    size_0 = ceil(size_q * d/4) - n           
    size_1 = ceil(size_q * d/4) - n           
    assert size_0 > 0, "torsion demandée trop élevée."

    seen = set()
    curves = []
    while len(curves) != nb_curves :
    
        e0 = randint(1,2^size_0) 
        e1 = randint(1,2^size_1)
        
        fd = (2^n)*e0
        ttd = [ 2*( (2^n)*e1 + 1 ), 2*( (2^n)*e1 + (2^(n-1))*e0 + 1) ]
        for td in ttd:
            for t1 in candidat_t1(e0,fd,e1,td,n):
                for q in inverse_rec_traces(d,td,t1):
                    Dd = td^2 - 4*q^d
                    dK = Dd/(fd^2)
                    if not is_discriminant(dK):
                        continue
                    D1 = t1^2 - 4*q
                    f1 = isqrt( D1/dK )
                    for f in diviseurs(f1,maximale):
                        D = dK*f^2
                        H = hilbert_class_polynomial(D)
                        for j0 in H.roots(ring=GF(q), multiplicities=False):
                            E = EllipticCurve(j=j0)
                            for Et in E.twists():
                                if any(Et.is_isomorphic(E) for E in seen):
                                    continue
                                assert Et.has_order(q + 1 - t1) or Et.has_order(q + 1 + t1)
                                seen.add(Et)
                                curves.append((Et,D))
                                if len(curves) == nb_curves:
                                    return curves

EllipticCurve_with_2torsion_degree(4,8,20)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 103
#      99                                 curves.append((Et,D))
#     100                                 if len(curves) == nb_curves:
#     101                                     return curves
#     102
# --> 103 EllipticCurve_with_2torsion_degree(Integer(4),Integer(8),Integer(20))
#
# Cell In[4], line 82, in EllipticCurve_with_2torsion_degree(d, n, size_q, size_disc, nb_curves, maximale)
#      78         fd = (Integer(2)**n)*e0
#      79         ttd = [ Integer(2)*( (Integer(2)**n)*e1 + Integer(1) ), Integer(2)*( (Integer(2)**n)*e1 + (Integer(2)**(n-Integer(1)))*e0 + Integer(1)) ]
#      80         for td in ttd:
#      81             for t1 in candidat_t1(e0,fd,e1,td,n):
# ---> 82                 for q in inverse_rec_traces(d,td,t1):
#      83                     Dd = td**Integer(2) - Integer(4)*q**d
#      84                     dK = Dd/(fd**Integer(2))
#      85                     if not is_discriminant(dK):
#
# Cell In[4], line 23, in inverse_rec_traces(d, td, t1)
#      19     row[-Integer(1)] = -t1
#      20     row[-Integer(2)] = Integer(2)
#      21     rows.append(row)
#      22     M = Matrix(PZ,rows)
# ---> 23     Ker = M.right_kernel()
#      24     base = Ker.gens()
#      25     assert base[Integer(0)][d] == Integer(1)
#      26     eq = (Integer(2)*base[Integer(0)])[Integer(0)] - td
#
# File sage/matrix/matrix2.pyx:5304, in sage.matrix.matrix2.Matrix.right_kernel()
# -> 5304 'Could not get source, probably due dynamically evaluated source code.'
#
# File sage/matrix/matrix2.pyx:4886, in sage.matrix.matrix2.Matrix.right_kernel_matrix()
# -> 4886 'Could not get source, probably due dynamically evaluated source code.'
#
# File sage/matrix/matrix2.pyx:4203, in sage.matrix.matrix2.Matrix._right_kernel_matrix_over_domain()
# -> 4203 'Could not get source, probably due dynamically evaluated source code.'
#
# File sage/matrix/matrix2.pyx:16832, in sage.matrix.matrix2.Matrix.smith_form()
# > 16832 'Could not get source, probably due dynamically evaluated source code.'
#
# File sage/matrix/matrix2.pyx:16832, in sage.matrix.matrix2.Matrix.smith_form()
# > 16832 'Could not get source, probably due dynamically evaluated source code.'
#
# File sage/matrix/matrix2.pyx:16832, in sage.matrix.matrix2.Matrix.smith_form()
# > 16832 'Could not get source, probably due dynamically evaluated source code.'
#
# File sage/matrix/matrix2.pyx:16839, in sage.matrix.matrix2.Matrix.smith_form()
# > 16839 'Could not get source, probably due dynamically evaluated source code.'
#
# File sage/matrix/matrix2.pyx:20434, in sage.matrix.matrix2._smith_diag()
# > 20434 'Could not get source, probably due dynamically evaluated source code.'
#
# File sage/rings/polynomial/polynomial_element.pyx:2774, in sage.rings.polynomial.polynomial_element.Polynomial.__truediv__()
# -> 2774 'Could not get source, probably due dynamically evaluated source code.'
#
# File sage/structure/element.pyx:2763, in sage.structure.element.RingElement._div_()
# -> 2763 'Could not get source, probably due dynamically evaluated source code.'
#
# File sage/structure/parent.pyx:901, in sage.structure.parent.Parent.__call__()
# --> 901 'Could not get source, probably due dynamically evaluated source code.'
#
# File sage/structure/coerce_maps.pyx:113, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_with_args()
# --> 113 'Could not get source, probably due dynamically evaluated source code.'
#
# File /var/tmp/sage-10.9/local/lib/python3.14/site-packages/sage/rings/fraction_field.py:755, in FractionField_generic._element_constructor_(self, x, y, coerce)
#     753     x, y = x.numerator() * y.denominator(), y.numerator() * x.denominator()
#     754 try:
# --> 755     return self._element_class(self, x, y, coerce=coerce)
#     756 except (TypeError, ValueError):
#     757     pass
#
# File cysignals/signals.pyx:357, in cysignals.signals.python_check_interrupt()
# --> 357 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt:

# %% [markdown]
# # Code : Génération de diamants

# %%
from sage.rings.finite_rings.integer_mod import square_root_mod_prime
from sage.rings.finite_rings.integer_mod import square_root_mod_prime_power
from sage.rings.number_field.order_ideal import NumberFieldOrderIdeal
import time


def Ideal_of_norm(l,D,f):

    #Trouver un idéal de norme l premier.
    #On se place dans un ordre de discriminant D et de conducteur f.

    K.<rK> = QuadraticField(D)
    dK = K.discriminant()
    K.<rK> = QuadraticField(dK)
    wK = (dK + rK)/2
    O = K.order([1,f*wK])
    
    if kronecker(D,l) == 1:
        D = Mod(D,l)
        sq = square_root_mod_prime(D,l)
        sm = Mod(-sq,l)
        sq = ZZ(sq)
        sm = ZZ(sm)
        sq = min(sm,sq)
        #print(sq)
        return NumberFieldOrderIdeal(O,[l, -sq + f*rK]) 
    elif kronecker(D,l) == 0:
        return NumberFieldOrderIdeal(O,[l, f*rK])
    else:
        raise "l est inerte"


def ideal_to_element(a,L,O):
    
    #On suppose a equivalent à L. On cherche alpha dans L tel que a = ( (alpha)bar / N(L))L.
    
    assert a.is_equivalent(L)
    B = a*(L.conjugate())
    alphabar = (B.gens_reduced())[0]
    alpha = alphabar.conjugate()
    assert NumberFieldOrderIdeal(O,alphabar) == B
    assert alpha in L
    return alpha

def element_to_ideal(alpha,L,O):
    
    #On suppose alpha dans L et on calcule l'idéal équivalent associé a = ( (alpha)bar / N(L))L.
    
    assert alpha in L
    alphabar = alpha.conjugate()
    B = NumberFieldOrderIdeal(O,alphabar)
    a2 = B*L
    if a2.is_principal():
        g = a2.gens_reduced()
        a = NumberFieldOrderIdeal(O,g[0]/(L.norm()))
    else:
        g1, g2 = a2.gens_reduced()
        a = NumberFieldOrderIdeal(O,[g1/(L.norm()), g2/(L.norm())])
    assert a.is_equivalent(L)
    return a

def make_liste_ideq(L,O,m,CE):   

    # On établit une liste d'idéaux équivalent à L, de normes minimales. 
    # paramètre m : Le nombre d'idéaux que l'on teste 2m^2 + m. 
    # On ne retient que les idéaux de normes premier avec CE.

    qL = L.quadratic_form()
    rL = qL.reduced_form()
    RL = NumberFieldOrderIdeal(O,rL)
    
    rK = O.number_field().gens()[0]
    f = O.conductor()
    alpha = rL[0]
    beta = (-rL[1] + f*rK)/2   #N'utilise pas LLL, contrairement à l'implémentation sage de Pegasis.
    
    liste_ideq = []
    
    for x in [0 .. m]:   
        for y in [-m .. m]:
            if (x != 0 or y > 0) and x.gcd(y) == 1:   #Pour ne pas calculer I et kI avec k entier.
                gamma = x*alpha + y*beta    #Pour ne pas creer gamma et -gamma, on evite les cas x < 0, ou (x = 0 et y <= 0), 
                
                if gamma == 0:
                    raise ValueError('erreur base courte liée') #n'est pas censé arriver. 
                    
                I = element_to_ideal(gamma,RL,O)
                NI = I.norm()
                if NI.gcd(CE) != 1:
                    continue
                    
                #liste_ideq.append([I,Nk,Ne,Ne_facto]) trier selon Nk ?
                i = len(liste_ideq)
                if NI == 1:
                    continue
                if i == 0:
                    liste_ideq.append([I,NI])
                else:
                    i = i-1
                    test = NI < liste_ideq[i][1]
                    while i > -1 and test :
                        i = i - 1
                        test = NI < liste_ideq[i][1]
                    liste_ideq.insert(i+1,[I,NI])

    return liste_ideq

def Ideal_random(D,f):
    
    l = next_prime(randint(10^20, 10^21))  #Pour générer un nombre premier aléatoire (une classe aléatoire)
    while kronecker(D,l) != 1:
        l = next_prime(l)

    L = Ideal_of_norm(l,D,f)
    return L

    
def T_diamant(E,D,f,Tmin,Tmax,L):
    
    #Paramètre par défaut : m_id pour le nombre d'idéaux testés
    p = E.base_ring().characteristic()
    m_id = isqrt(p.nbits())+1
    
    #Retourne un diamant de taille divisant T, sans idéaux friables ni endomorphismes
    K.<rK> = QuadraticField(D)
    dK = K.discriminant()
    K.<rK> = QuadraticField(dK)
    wK = (dK + rK)/2
    O = K.order([1,f*wK])
    
    assert O.conductor() == f and O.discriminant() == D and D == (f^2)*dK
    
    CE = E.cardinality_pari()
    
    liste_ideq = make_liste_ideq(L,O,m_id,CE)
    
    k_id = len(liste_ideq)
    sols = []
    sols_ext = []
    tentatives = 0

    #Parcourir les couples d'idéaux minimsant Nk1Nk2 - Nk1 - Nk2

    for i in [0 .. k_id-2]:
        b_prep = liste_ideq[i]
        b, N1 = b_prep
        
        for j in [i+1 .. k_id-1]:
            c_prep = liste_ideq[j]
            c, N2 = c_prep
            
            tentatives = tentatives + 1
            
            if N1.gcd(N2) != 1 or (N1 + N2) < Tmin:
                continue
                
            if Tmax % (N1 + N2) == 0:
                print('diamant:',N1,'+',N2,'=',N1 + N2)
                print('tentatives :', tentatives)
                print('indices idéaux :', i, j)
                return [N1,N2,N1 + N2,b,c]

    raise ValueError("Aucune solution trouvée")

# %%
[E,D,f,T] = (EllipticCurve_with_Torsion(2,32,14,4))[0]

l = 116617643378184942397 #Pour garder le même exemple

L = Ideal_of_norm(l,D,f)
print(L.quadratic_form().reduced_form())
T_diamant(E,D,f,16,T,L)
# Out:
# x^2 + x*y + 10*y^2
# diamant: 75 + 181 = 256
# tentatives : 70
# indices idéaux : 5 10
# [75,
#  181,
#  256,
#  Ideal (13/2*rK + 3/2, 25*rK) of Maximal Order generated by 1/2*rK + 1/2 in Number Field in rK with defining polynomial x^2 + 39 with rK = 6.244997998398398?*I,
#  Ideal (109/2*rK + 1/2, 181*rK) of Maximal Order generated by 1/2*rK + 1/2 in Number Field in rK with defining polynomial x^2 + 39 with rK = 6.244997998398398?*I]

# %%
E,D,f,T
# Out:
# (Elliptic Curve defined by y^2 = x^3 + 2857265638*x + 3935716393 over Finite Field of size 4295049217,
#  -39,
#  1,
#  16384)

# %%
[E,D,f,T] = (EllipticCurve_with_Torsion(2,32,14,4))[0]
L = Ideal_random(D,f)
print(L.is_principal(), L.quadratic_form().reduced_form())
T_diamant(E,D,f,32,T,L)
# Out:
# False 2*x^2 - x*y + 5*y^2
# diamant: 5 + 59 = 64
# tentatives : 6
# indices idéaux : 0 6
# [5,
#  59,
#  64,
#  Ideal (9/2*rK + 1/2, 5*rK) of Maximal Order generated by 1/2*rK + 1/2 in Number Field in rK with defining polynomial x^2 + 39 with rK = 6.244997998398398?*I,
#  Ideal (107/2*rK + 1/2, 59*rK) of Maximal Order generated by 1/2*rK + 1/2 in Number Field in rK with defining polynomial x^2 + 39 with rK = 6.244997998398398?*I]

# %% [markdown]
# # Recherche d'exemple

# %%
Candidats = EllipticCurve_with_Torsion(2,32,8,2,nb_curves = 34)
Candidats
# Out:
# [[Elliptic Curve defined by y^2 = x^3 + 2857265638*x + 3935716393 over Finite Field of size 4295049217,
#   -39,
#   1,
#   16384],
#  [Elliptic Curve defined by y^2 = x^3 + 171428965*x + 4017496321 over Finite Field of size 4295049217,
#   -39,
#   1,
#   16384],
#  [Elliptic Curve defined by y^2 = x^3 + 3882545834*x + 1752773000 over Finite Field of size 4295049217,
#   -39,
#   1,
#   16384],
#  [Elliptic Curve defined by y^2 = x^3 + 2533512917*x + 1945338383 over Finite Field of size 4295049217,
#   -39,
#   1,
#   16384],
#  [Elliptic Curve defined by y^2 = x^3 + 3154265514*x + 290914691 over Finite Field of size 4295009281,
#   -87,
#   1,
#   1024],
#  [Elliptic Curve defined by y^2 = x^3 + 1182229990*x + 3496634123 over Finite Field of size 4295009281,
#   -87,
#   1,
#   1024],
#  [Elliptic Curve defined by y^2 = x^3 + 605878322*x + 495876985 over Finite Field of size 4295009281,
#   -87,
#   1,
#   1024],
#  [Elliptic Curve defined by y^2 = x^3 + 1045312390*x + 1580900909 over Finite Field of size 4295009281,
#   -87,
#   1,
#   1024],
#  [Elliptic Curve defined by y^2 = x^3 + 2984514877*x + 32957308 over Finite Field of size 4295009281,
#   -87,
#   1,
#   1024],
#  [Elliptic Curve defined by y^2 = x^3 + 2529508521*x + 382943595 over Finite Field of size 4295009281,
#   -87,
#   1,
#   1024],
#  [Elliptic Curve defined by y^2 = x^3 + 1418308154*x + 2561383340 over Finite Field of size 4294914049,
#   -95,
#   1,
#   4096],
#  [Elliptic Curve defined by y^2 = x^3 + 3942005180*x + 2747420246 over Finite Field of size 4294914049,
#   -95,
#   1,
#   4096],
#  [Elliptic Curve defined by y^2 = x^3 + 3236839003*x + 4191086421 over Finite Field of size 4294914049,
#   -95,
#   1,
#   4096],
#  [Elliptic Curve defined by y^2 = x^3 + 3546729627*x + 1009190502 over Finite Field of size 4294914049,
#   -95,
#   1,
#   4096],
#  [Elliptic Curve defined by y^2 = x^3 + 71525988*x + 587361606 over Finite Field of size 4294914049,
#   -95,
#   1,
#   4096],
#  [Elliptic Curve defined by y^2 = x^3 + 2599315541*x + 436104493 over Finite Field of size 4294914049,
#   -95,
#   1,
#   4096],
#  [Elliptic Curve defined by y^2 = x^3 + 843221875*x + 2935422540 over Finite Field of size 4294914049,
#   -95,
#   1,
#   4096],
#  [Elliptic Curve defined by y^2 = x^3 + 3007746471*x + 1692635312 over Finite Field of size 4294914049,
#   -95,
#   1,
#   4096],
#  [Elliptic Curve defined by y^2 = x^3 + 1241507901*x + 3025505477 over Finite Field of size 4295021057,
#   -151,
#   1,
#   512],
#  [Elliptic Curve defined by y^2 = x^3 + 972677225*x + 3970535451 over Finite Field of size 4295021057,
#   -151,
#   1,
#   512],
#  [Elliptic Curve defined by y^2 = x^3 + 2650514217*x + 3596872814 over Finite Field of size 4295021057,
#   -151,
#   1,
#   512],
#  [Elliptic Curve defined by y^2 = x^3 + 2995061410*x + 2388664072 over Finite Field of size 4295021057,
#   -151,
#   1,
#   512],
#  [Elliptic Curve defined by y^2 = x^3 + 54126094*x + 3343648465 over Finite Field of size 4295021057,
#   -151,
#   1,
#   512],
#  [Elliptic Curve defined by y^2 = x^3 + 1783294872*x + 982899828 over Finite Field of size 4295021057,
#   -151,
#   1,
#   512],
#  [Elliptic Curve defined by y^2 = x^3 + 1356013064*x + 4277824592 over Finite Field of size 4295021057,
#   -151,
#   1,
#   512],
#  [Elliptic Curve defined by y^2 = x^3 + 3480206989*x + 3350195143 over Finite Field of size 4294913537,
#   -151,
#   1,
#   512],
#  [Elliptic Curve defined by y^2 = x^3 + 2642814372*x + 2018424016 over Finite Field of size 4294913537,
#   -151,
#   1,
#   512],
#  [Elliptic Curve defined by y^2 = x^3 + 4096508143*x + 2581481346 over Finite Field of size 4294913537,
#   -151,
#   1,
#   512],
#  [Elliptic Curve defined by y^2 = x^3 + 176513861*x + 522553147 over Finite Field of size 4294913537,
#   -151,
#   1,
#   512],
#  [Elliptic Curve defined by y^2 = x^3 + 2900144093*x + 1320667249 over Finite Field of size 4294913537,
#   -151,
#   1,
#   512],
#  [Elliptic Curve defined by y^2 = x^3 + 2071618348*x + 2752943267 over Finite Field of size 4294913537,
#   -151,
#   1,
#   512],
#  [Elliptic Curve defined by y^2 = x^3 + 3637736958*x + 3980986699 over Finite Field of size 4294913537,
#   -151,
#   1,
#   512],
#  [Elliptic Curve defined by y^2 = x^3 + 106832189*x + 2859999312 over Finite Field of size 4295049217,
#   -156,
#   2,
#   8192],
#  [Elliptic Curve defined by y^2 = x^3 + 3697211983*x + 4162463574 over Finite Field of size 4295049217,
#   -156,
#   2,
#   8192]]

# %%
[E,D,f,T] = Candidats[33]
E,D,f,T
# Out:
# (Elliptic Curve defined by y^2 = x^3 + 3697211983*x + 4162463574 over Finite Field of size 4295049217,
#  -156,
#  2,
#  8192)

# %%
L = Ideal_random(D,f)
print(L.quadratic_form().reduced_form())
T_diamant(E,D,f,32,T,L)
# Out:
# 5*x^2 + 2*x*y + 8*y^2
# diamant: 5 + 59 = 64
# tentatives : 6
# indices idéaux : 0 6
# [5,
#  59,
#  64,
#  Ideal (4*rK + 1, 5*rK) of Order of conductor 2 generated by rK in Number Field in rK with defining polynomial x^2 + 39 with rK = 6.244997998398398?*I,
#  Ideal (48*rK + 1, 59*rK) of Order of conductor 2 generated by rK in Number Field in rK with defining polynomial x^2 + 39 with rK = 6.244997998398398?*I]
